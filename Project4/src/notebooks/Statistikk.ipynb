# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('../../data/equi_long3.csv')
df
# Out:
#        T  spins          cycles  ordered  delay         E         M      Mabs  \
# 0    1.0    400      100.000000       -1      0 -1.997465 -0.999358  0.999358
# 1    1.0    400      137.382380       -1      0 -1.992654 -0.996764  0.996764
# 2    1.0    400      188.739182       -1      0 -1.989765 -0.995483  0.995483
# 3    1.0    400      259.294380       -1      0 -1.995057 -0.998156  0.998156
# 4    1.0    400      356.224789       -1      0 -1.995390 -0.998501  0.998501
# ..   ...    ...             ...      ...    ...       ...       ...       ...
# 175  2.4    400   280721.620394        1      0 -1.237885  0.051293  0.454574
# 176  2.4    400   385662.042116        1      0 -1.236644  0.004756  0.452345
# 177  2.4    400   529831.690628        1      0 -1.235572 -0.005419  0.450227
# 178  2.4    400   727895.384398        1      0 -1.237755 -0.016890  0.454879
# 179  2.4    400  1000000.000000        1      0 -1.236821  0.002373  0.454058
#
#            cv   suscept   accepted
# 0    0.020696  0.001350         28
# 1    4.447077  1.110154         32
# 2    6.245184  1.559708         46
# 3    1.831680  0.454714         86
# 4    1.032657  0.253825        116
# ..        ...       ...        ...
# 175  1.404608  8.986125   30204774
# 176  1.410451  8.890327   41569851
# 177  1.408659  8.872454   57195137
# 178  1.415618  8.843787   78329985
# 179  1.408462  8.823934  107736644
#
# [180 rows x 11 columns]

# %%
df['E'] = np.abs(df['E'])
sel = df.loc[(df['ordered']==0) & (df['T']==2.4)]
sel.plot('cycles','E',logx=True,logy=True)

sel.plot('cycles','suscept',logx=True,logy=True)
sel.plot('cycles','cv',logx=True,logy=True)

# %%
fig, ax = plt.subplots(1)
fig,ax2 = plt.subplots(1)
for L in [40,60,80,100]:
    sel = df.loc[df['spins']==L**2]
    print(sel.std())
    sel.plot('T','cv',ax=ax)
    sel.plot('T','Mabs',ax=ax2)
# Out:
# T           2.326889e-01
# spins       0.000000e+00
# cycles      0.000000e+00
# ordered     0.000000e+00
# delay       0.000000e+00
# E           2.738568e-01
# M           4.610557e-01
# Mabs        3.197703e-01
# cv          4.378183e-01
# suscept     8.887444e+00
# accepted    1.048061e+08
# dtype: float64
# T           2.326889e-01
# spins       0.000000e+00
# cycles      0.000000e+00
# ordered     0.000000e+00
# delay       0.000000e+00
# E           2.734876e-01
# M           4.729606e-01
# Mabs        3.390566e-01
# cv          4.608017e-01
# suscept     1.710425e+01
# accepted    2.355357e+08
# dtype: float64
# T           2.326889e-01
# spins       0.000000e+00
# cycles      0.000000e+00
# ordered     0.000000e+00
# delay       0.000000e+00
# E           2.733854e-01
# M           4.786091e-01
# Mabs        3.501697e-01
# cv          4.695922e-01
# suscept     2.529200e+01
# accepted    4.183665e+08
# dtype: float64
# T           2.326889e-01
# spins       0.000000e+00
# cycles      0.000000e+00
# ordered     0.000000e+00
# delay       0.000000e+00
# E           2.733761e-01
# M           4.763360e-01
# Mabs        3.572130e-01
# cv          4.796261e-01
# suscept     3.538595e+01
# accepted    6.534677e+08
# dtype: float64
